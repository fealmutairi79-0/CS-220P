# %% [markdown]
# <a href="https://colab.research.google.com/github/fealmutairi79-0/CS-220P/blob/main/notebooks/lecture-4-part-1e.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pathlib

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import compose, datasets, linear_model, metrics, model_selection
from sklearn import preprocessing, pipeline

# %% [markdown]
# # Regularized Linear Models

# %%
features, targets = datasets.load_diabetes(
    return_X_y=True,
    as_frame=True,
    scaled=False
)

# %%
features.head()
# Out:
#     age  sex   bmi     bp     s1     s2    s3   s4      s5    s6
# 0  59.0  2.0  32.1  101.0  157.0   93.2  38.0  4.0  4.8598  87.0
# 1  48.0  1.0  21.6   87.0  183.0  103.2  70.0  3.0  3.8918  69.0
# 2  72.0  2.0  30.5   93.0  156.0   93.6  41.0  4.0  4.6728  85.0
# 3  24.0  1.0  25.3   84.0  198.0  131.4  40.0  5.0  4.8903  89.0
# 4  50.0  1.0  23.0  101.0  192.0  125.4  52.0  4.0  4.2905  80.0

# %%
targets.head()
# Out:
# 0    151.0
# 1     75.0
# 2    141.0
# 3    206.0
# 4    135.0
# Name: target, dtype: float64

# %% [markdown]
# ### Train-test split

# %%
prng = np.random.RandomState(42)

train_features, test_features, train_targets, test_targets = (
    model_selection.train_test_split(
        features,
        targets,
        random_state=prng,
        test_size=0.1
    )
)

# %% [markdown]
# ## Feature Preprocessing

# %%
transformer_1 = compose.make_column_transformer(
    (
        preprocessing.OneHotEncoder(
            drop="first",
            dtype=np.uint8,
            sparse_output=False,
        ),
        ["sex"]
    ),
    remainder="drop",
    verbose=True,
    verbose_feature_names_out=False
)


transformer_2 = compose.make_column_transformer(
    (
        preprocessing.StandardScaler(),
        ["age", "bmi", "bp", "s1", "s2", "s3", "s4", "s5"]
    ),
    remainder="drop",
    verbose=True,
    verbose_feature_names_out=False
)

features_preprocessor = pipeline.make_union(
    transformer_1,
    transformer_2,
    verbose=True,
    n_jobs=-1
).set_output(transform="pandas")

# %%
features_preprocessor
# Out:
# FeatureUnion(n_jobs=-1,
#              transformer_list=[('columntransformer-1',
#                                 ColumnTransformer(transformers=[('onehotencoder',
#                                                                  OneHotEncoder(drop='first',
#                                                                                dtype=<class 'numpy.uint8'>,
#                                                                                sparse_output=False),
#                                                                  ['sex'])],
#                                                   verbose=True,
#                                                   verbose_feature_names_out=False)),
#                                ('columntransformer-2',
#                                 ColumnTransformer(transformers=[('standardscaler',
#                                                                  StandardScaler(),
#                                                                  ['age', 'bmi',
#                                                                   'bp', 's1',
#                                                                   's2', 's3',
#                                                                   's4',
#                                                                   's5'])],
#                                                   verbose=True,
#                                                   verbose_feature_names_out=False))],
#              verbose=True)

# %% [markdown]
# ## Target Preprocessing

# %%
target_preprocessor = preprocessing.FunctionTransformer(
    func=np.log,
    inverse_func=np.exp
)

# %%
target_preprocessor
# Out:
# FunctionTransformer(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>)

# %% [markdown]
# ## Feature Engineering

# %%
feature_engineering = preprocessing.PolynomialFeatures(
    degree=2,
    include_bias=False,#constant term
    interaction_only=False
).set_output(transform="pandas")

# %%
feature_engineering
# Out:
# PolynomialFeatures(include_bias=False)

# %% [markdown]
# ## Model training

# %% [markdown]
# ### Using ElasticNet

# %%
_regressor = compose.TransformedTargetRegressor(
    linear_model.ElasticNet(
        alpha=1e-3,
        l1_ratio=0.5,
        max_iter=4096,
        fit_intercept=True,
        random_state=prng,
    ),
    transformer=target_preprocessor
)

elastic_net_pipeline = pipeline.make_pipeline(
    features_preprocessor,
    feature_engineering,
    _regressor
)

# %%
_ = elastic_net_pipeline.fit(train_features, train_targets)

# %%
train_predictions = elastic_net_pipeline.predict(train_features)
train_rmse = metrics.root_mean_squared_error(
    train_targets,
    train_predictions,
)
print(f"Training rmse: {train_rmse}")
# Out:
# Training rmse: 52.10772518068729

# %% [markdown]
# ### Using SGDRegressor

# %%
linear_model.SGDRegressor?

# %%
_regressor = compose.TransformedTargetRegressor(
    linear_model.SGDRegressor(
        penalty="elasticnet",
        alpha=1e-3,
        l1_ratio=0.5,
        fit_intercept=True,
    ),
    transformer=target_preprocessor
)

sgd_regressor_pipeline = pipeline.make_pipeline(
    features_preprocessor,
    feature_engineering,
    _regressor
)

# %%
_ = sgd_regressor_pipeline.fit(train_features, train_targets)

# %%
train_predictions = sgd_regressor_pipeline.predict(train_features)
train_rmse = metrics.root_mean_squared_error(
    train_targets,
    train_predictions,
)
print(f"Training rmse: {train_rmse}")
# Out:
# Training rmse: 55.88367768217637

# %% [markdown]
# ## Model assessment

# %%
cv_neg_mses = model_selection.cross_val_score(
    elastic_net_pipeline,
    train_features,
    train_targets,
    cv=5,
    n_jobs=-1,
    scoring="neg_root_mean_squared_error",
    verbose=1
)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.3s finished

# %%
cv_rmse = np.mean(-cv_neg_mses)
print(f"ElasticNet CV rmse: {cv_rmse}")
# Out:
# ElasticNet CV rmse: 58.95329225659996

# %%
cv_neg_mses = model_selection.cross_val_score(
    sgd_regressor_pipeline,
    train_features,
    train_targets,
    cv=5,
    n_jobs=-1,
    scoring="neg_root_mean_squared_error",
    verbose=1
)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.4s finished

# %%
cv_rmse = np.mean(-cv_neg_mses)
print(f"SGDRegressor CV rmse: {cv_rmse}")
# Out:
# SGDRegressor CV rmse: 69.86024253499669

# %% [markdown]
# ### Exercise:
#
# Is our current model under-fitting or over-fitting? How can you tell? What can you do to fix the problem?

# %% [markdown]
# ## Tuning model performance

# %% [markdown]
# ### Using ElasticNetCV
#
# [ElasticNetCV](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.ElasticNetCV.html) is an example of a [cross-validation estimator](https://scikit-learn.org/stable/glossary.html#term-cross-validation-estimator). Cross-validation estimators are named `EstimatorCV` and tend to be roughly equivalent to `GridSearchCV(Estimator(), ...)`. The advantage of using a cross-validation estimator over the canonical estimator class along with grid search is that they can take advantage of warm-starting by reusing precomputed results in the previous steps of the cross-validation process.
#
# When calling `fit`, once the best parameters `l1_ratio` and `alpha` are found through cross-validation, the model is `fit` again using the entire training set.

# %%
linear_model.ElasticNetCV?

# %%
regressor_cv = compose.TransformedTargetRegressor(
    linear_model.ElasticNetCV(
        cv=5,
        eps=1e-3,
        fit_intercept=True,
        l1_ratio=np.logspace(-1, 0, 10),
        max_iter=8192,
        alphas=np.logspace(-4, 0, 10),
        n_jobs=-1,
        random_state=prng,
        selection="random",
        verbose=0,
    ),
    transformer=target_preprocessor
)

tuned_elastic_net_pipeline = pipeline.make_pipeline(
    features_preprocessor,
    feature_engineering,
    regressor_cv,
    verbose=True
)

# %%
tuned_elastic_net_pipeline
# Out:
# Pipeline(steps=[('featureunion',
#                  FeatureUnion(n_jobs=-1,
#                               transformer_list=[('columntransformer-1',
#                                                  ColumnTransformer(transformers=[('onehotencoder',
#                                                                                   OneHotEncoder(drop='first',
#                                                                                                 dtype=<class 'numpy.uint8'>,
#                                                                                                 sparse_output=False),
#                                                                                   ['sex'])],
#                                                                    verbose=True,
#                                                                    verbose_feature_names_out=False)),
#                                                 ('columntransformer-2',
#                                                  ColumnTransformer(transformers=[('standardscaler',...
#        5.99484250e-03, 1.66810054e-02, 4.64158883e-02, 1.29154967e-01,
#        3.59381366e-01, 1.00000000e+00]),
#                                                                    cv=5,
#                                                                    l1_ratio=array([0.1       , 0.12915497, 0.16681005, 0.21544347, 0.27825594,
#        0.35938137, 0.46415888, 0.59948425, 0.77426368, 1.        ]),
#                                                                    max_iter=8192,
#                                                                    n_jobs=-1,
#                                                                    random_state=RandomState(MT19937) at 0x7EDDC9F5DF40,
#                                                                    selection='random'),
#                                             transformer=FunctionTransformer(func=<ufunc 'log'>,
#                                                                             inverse_func=<ufunc 'exp'>)))],
#          verbose=True)

# %%
_ = tuned_elastic_net_pipeline.fit(train_features, train_targets)
# Out:
# [Pipeline] ...... (step 1 of 3) Processing featureunion, total=   3.2s
# [Pipeline]  (step 2 of 3) Processing polynomialfeatures, total=   0.0s
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01625047116314704, tolerance: 0.010189525278059238
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.073459892244845, tolerance: 0.009860708779601497
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.759826170594783, tolerance: 0.010189525278059238
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17.71393069110199, tolerance: 0.009860708779601497
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18.44350465509938, tolerance: 0.010189525278059238
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08935543672929924, tolerance: 0.010168606944038682
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02723984685060543, tolerance: 0.009481286676427463
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.3977738962554085, tolerance: 0.010168606944038682
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.869766063564338, tolerance: 0.009481286676427463
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17.857466781866286, tolerance: 0.010168606944038682
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.663370610130457, tolerance: 0.009481286676427463
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.2312170955804085, tolerance: 0.009908895976788816
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.077360660543555, tolerance: 0.010189525278059238
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.626925792837255, tolerance: 0.009908895976788816
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.26854810544667, tolerance: 0.010189525278059238
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04803234596017347, tolerance: 0.010168606944038682
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.6645478076953, tolerance: 0.010168606944038682
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.199462998761504, tolerance: 0.009860708779601497
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17.166139567456177, tolerance: 0.010168606944038682
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.954953050111936, tolerance: 0.009860708779601497
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.947422423426147, tolerance: 0.009908895976788816
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6080940388827756, tolerance: 0.009481286676427463
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.564687922070945, tolerance: 0.009908895976788816
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.489804909081938, tolerance: 0.009481286676427463
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.151041576982109, tolerance: 0.010189525278059238
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.0880267583490166, tolerance: 0.009860708779601497
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.948211009036456, tolerance: 0.010189525278059238
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.035624710855098, tolerance: 0.009860708779601497
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.017199257678619517, tolerance: 0.010168606944038682
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.246362299180401, tolerance: 0.010168606944038682
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1280991951147428, tolerance: 0.009481286676427463
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.992118176725215, tolerance: 0.010168606944038682
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.737736946513351, tolerance: 0.009481286676427463
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.125064261832108, tolerance: 0.009908895976788816
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.028982232691604, tolerance: 0.010189525278059238
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.655810000214924, tolerance: 0.009908895976788816
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.26990438696692, tolerance: 0.010189525278059238
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9549807028876813, tolerance: 0.009860708779601497
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.3890902197422577, tolerance: 0.010168606944038682
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.668378563873611, tolerance: 0.009860708779601497
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.885766934649634, tolerance: 0.010168606944038682
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.511120367248214, tolerance: 0.009908895976788816
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5181101532331951, tolerance: 0.009481286676427463
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.297678404813828, tolerance: 0.009908895976788816
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.28155796038598, tolerance: 0.009481286676427463
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5379572286065724, tolerance: 0.009860708779601497
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.584380243900842, tolerance: 0.010189525278059238
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.050066792889742, tolerance: 0.009860708779601497
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.649276204318774, tolerance: 0.010189525278059238
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11796756759758864, tolerance: 0.009481286676427463
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.144251336536829, tolerance: 0.010168606944038682
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.380982444679452, tolerance: 0.009481286676427463
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.734745588623037, tolerance: 0.010168606944038682
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3741653575120267, tolerance: 0.009908895976788816
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.931774374164762, tolerance: 0.009908895976788816
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3928918002375994, tolerance: 0.010189525278059238
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.641426198084337, tolerance: 0.010189525278059238
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04631000432210186, tolerance: 0.009860708779601497
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.872938735236481, tolerance: 0.009860708779601497
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9877768670751692, tolerance: 0.010168606944038682
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.801635707783241, tolerance: 0.010168606944038682
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04031873300669275, tolerance: 0.009481286676427463
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.4613228638344395, tolerance: 0.009481286676427463
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.130630587286646, tolerance: 0.009908895976788816
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.046268953682166, tolerance: 0.009908895976788816
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2991666776396258, tolerance: 0.010189525278059238
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.106542066011656, tolerance: 0.010189525278059238
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.470388707249654, tolerance: 0.009860708779601497
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07916172400471311, tolerance: 0.010168606944038682
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.966159804971372, tolerance: 0.010168606944038682
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.395593663026595, tolerance: 0.009481286676427463
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.05120770948686, tolerance: 0.009908895976788816
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.674508515793075, tolerance: 0.010189525278059238
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.211631892520188, tolerance: 0.009860708779601497
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.82394023352613, tolerance: 0.010168606944038682
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.050615708479867294, tolerance: 0.009481286676427463
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.073481702313462, tolerance: 0.009908895976788816
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.634864633245201, tolerance: 0.009481286676427463
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.76474138178644, tolerance: 0.010189525278059238
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.120218110517065, tolerance: 0.009860708779601497
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.473942172016827, tolerance: 0.010168606944038682
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1810355944168478, tolerance: 0.009481286676427463
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6026406752723688, tolerance: 0.009481286676427463
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.499808014408959, tolerance: 0.009908895976788816
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.204286722134885, tolerance: 0.010189525278059238
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.749625490375351, tolerance: 0.009860708779601497
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03677174789236659, tolerance: 0.010168606944038682
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.756084081820184, tolerance: 0.010168606944038682
#   model = cd_fast.enet_coordinate_descent_gram(
# [Pipeline]  (step 3 of 3) Processing transformedtargetregressor, total=   5.8s
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1684486003271246, tolerance: 0.009481286676427463
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0559625737918452, tolerance: 0.009908895976788816
#   model = cd_fast.enet_coordinate_descent_gram(

# %%
(
    tuned_elastic_net_pipeline.named_steps["transformedtargetregressor"]
                              .regressor_
                              .alpha_
)
# Out:
# np.float64(0.016681005372000592)

# %%
(
    tuned_elastic_net_pipeline.named_steps["transformedtargetregressor"]
                              .regressor_
                              .l1_ratio_
)
# Out:
# np.float64(0.5994842503189409)

# %% [markdown]
# ### Using GridSearchCV and SGDRegressor

# %%
tuned_sgd_regressor_pipeline = model_selection.GridSearchCV(
    sgd_regressor_pipeline,
    cv=5,
    param_grid={
        "transformedtargetregressor__regressor__alpha": np.logspace(-4, 0, 10),
        "transformedtargetregressor__regressor__l1_ratio": np.logspace(-1, 0, 10)
    },
    n_jobs=-1,
    refit=True,
    scoring="neg_root_mean_squared_error",
    verbose=1
)

# %%
tuned_sgd_regressor_pipeline
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('featureunion',
#                                         FeatureUnion(n_jobs=-1,
#                                                      transformer_list=[('columntransformer-1',
#                                                                         ColumnTransformer(transformers=[('onehotencoder',
#                                                                                                          OneHotEncoder(drop='first',
#                                                                                                                        dtype=<class 'numpy.uint8'>,
#                                                                                                                        sparse_output=False),
#                                                                                                          ['sex'])],
#                                                                                           verbose=True,
#                                                                                           verbose_feature_names_out=False)),
#                                                                        ('columntransformer-2',
#                                                                         ColumnTransformer(tran...
#              param_grid={'transformedtargetregressor__regressor__alpha': array([1.00000000e-04, 2.78255940e-04, 7.74263683e-04, 2.15443469e-03,
#        5.99484250e-03, 1.66810054e-02, 4.64158883e-02, 1.29154967e-01,
#        3.59381366e-01, 1.00000000e+00]),
#                          'transformedtargetregressor__regressor__l1_ratio': array([0.1       , 0.12915497, 0.16681005, 0.21544347, 0.27825594,
#        0.35938137, 0.46415888, 0.59948425, 0.77426368, 1.        ])},
#              scoring='neg_root_mean_squared_error', verbose=1)

# %%
_ = tuned_sgd_regressor_pipeline.fit(train_features, train_targets)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits

# %%
tuned_sgd_regressor_pipeline.best_params_
# Out:
# {'transformedtargetregressor__regressor__alpha': np.float64(0.12915496650148828),
#  'transformedtargetregressor__regressor__l1_ratio': np.float64(0.16681005372000587)}

# %% [markdown]
# ## Assessing performance of the tuned model

# %%
train_predictions = tuned_elastic_net_pipeline.predict(train_features)
train_rmse = metrics.root_mean_squared_error(
    train_targets,
    train_predictions,
)
print(f"ElasticNetCV training rmse: {train_rmse}")
# Out:
# ElasticNetCV training rmse: 53.790943395498914

# %%
test_predictions = tuned_elastic_net_pipeline.predict(test_features)
test_rmse = metrics.root_mean_squared_error(
    test_targets,
    test_predictions,
)
print(f"ElasticNetCV testing rmse: {test_rmse}")
# Out:
# ElasticNetCV testing rmse: 53.88215698076754

# %%
train_predictions = tuned_sgd_regressor_pipeline.predict(train_features)
train_rmse = metrics.root_mean_squared_error(
    train_targets,
    train_predictions,
)
print(f"GridSearchCV + SGDRegressor training rmse: {train_rmse}")
# Out:
# GridSearchCV + SGDRegressor training rmse: 57.52091081582808

# %%
test_predictions = tuned_sgd_regressor_pipeline.predict(test_features)
test_rmse = metrics.root_mean_squared_error(
    test_targets,
    test_predictions,
)
print(f"GridSearchCV + SGDRegressor Testing rmse: {test_rmse}")
# Out:
# GridSearchCV + SGDRegressor Testing rmse: 55.57813519134998

# %% [markdown]
# ### Exercise
#
# Which of the two models should you prefer? Why?
